# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import numpy as np

# %% [markdown]
# ### Task 1
#
# For the tennis example predict the class for the input ```{outlook = Overcast, temp = Hot, humidity = Normal, wind = Strong}```.

# %%
dfr=pd.read_csv('tennis.csv')
dfr
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
P_play_yes_outlook_sunny = len(dfr[(dfr['outlook']=='Sunny') & (dfr['play'] == 'Yes')])/len(dfr[dfr['play'] == 'Yes'])
P_play_yes_temp_hot = len(dfr[(dfr['temp']=='Hot') & (dfr['play'] == 'Yes')])/len(dfr[dfr['play'] == 'Yes'])
P_play_yes_humidity_normal = len(dfr[(dfr['humidity']=='Normal') & (dfr['play'] == 'Yes')])/len(dfr[dfr['play'] == 'Yes'])
P_play_yes_wind_strong = len(dfr[(dfr['wind']=='Strong') & (dfr['play'] == 'Yes')])/len(dfr[dfr['play'] == 'Yes'])

P_play_no_outlook_sunny = len(dfr[(dfr['outlook']=='Sunny') & (dfr['play'] == 'No')])/len(dfr[dfr['play'] == 'No'])
P_play_no_temp_hot = len(dfr[(dfr['temp']=='Hot') & (dfr['play'] == 'No')])/len(dfr[dfr['play'] == 'No'])
P_play_no_humidity_normal = len(dfr[(dfr['humidity']=='Normal') & (dfr['play'] == 'No')])/len(dfr[dfr['play'] == 'No'])
P_play_no_wind_strong = len(dfr[(dfr['wind']=='Strong') & (dfr['play'] == 'No')])/len(dfr[dfr['play'] == 'No'])
print(f"P(outlook = Sunny|play = Yes) = {P_play_yes_outlook_sunny:.2f}",)
print(f"P(temp=hot|play = Yes) = {P_play_yes_temp_hot:.2f}")
print(f"P(humidity=normal|play = Yes) = {P_play_yes_humidity_normal:.2f}")
print(f"P(wind=strong|play = Yes) = {P_play_yes_wind_strong:.2f}")

print(f"P(outlook = Sunny|play = No) ={P_play_no_outlook_sunny:.2f} ")
print(f"P(temp=hot|play = No) = {P_play_no_temp_hot:.2f}")
print(f"P(humidity=normal|play = No) ={P_play_no_humidity_normal:.2f} ")
print(f"P(wind=strong|play = No) = {P_play_no_wind_strong:.2f}")
# Out:
# P(outlook = Sunny|play = Yes) = 0.22
# P(temp=hot|play = Yes) = 0.22
# P(humidity=normal|play = Yes) = 0.67
# P(wind=strong|play = Yes) = 0.33
# P(outlook = Sunny|play = No) =0.60
# P(temp=hot|play = No) = 0.40
# P(humidity=normal|play = No) =0.20
# P(wind=strong|play = No) = 0.60

# %%
P_play_yes=len(dfr[dfr['play'] == 'Yes'])/len(dfr['play'])
P_play_no=len(dfr[dfr['play'] == 'No'])/len(dfr['play'])
print(f"P(play = Yes)= {P_play_yes:.2f}")
print(f"P(play = No)= {P_play_no:.2f}")
# Out:
# P(play = Yes)= 0.64
# P(play = No)= 0.36

# %%
a=P_play_yes_outlook_sunny*P_play_yes_temp_hot*P_play_yes_humidity_normal*P_play_yes_wind_strong*P_play_yes
b=P_play_no_outlook_sunny*P_play_no_temp_hot*P_play_no_humidity_normal*P_play_no_wind_strong*P_play_no
if a>b:
 P_play_no=a/(a+b)
 print(f"P(play = No)= {P_play_no:.2f}")
elif a<b:
    print(f"P(play = Yes)= {P_play_yes:.2f}")
# Out:
# P(play = Yes)= 0.64

# %% [markdown]
# the class for input {outlook = Overcast, temp = Hot, humidity = Normal, wind = Strong} is play

# %% [markdown]
# ### Task 2
#
# The dataset ```lenses_train.csv``` contains a training dataset on contact lense type suitable for various kinds of patients. The file ```lenses_test.csv``` has a (very small) test dataset. A brief description of the variables is given in ```lenses.txt```. The last columns is the class to be predicted.
#
# Task is to build a naive Bayes classifier to predict the ```contact``` class. Use the ```lenses_test.csv``` to test your model.
#
# Because now all variables are of categorical type, use of counting to find the probabilities is applicable. The needed probabilities can be calculated manually or by using ```pandas``` dataframes methods. The latter should be less time consuming.

# %%
dftrn = pd.read_csv('lenses_train.csv',index_col = 0)
dftest = pd.read_csv('lenses_test.csv',index_col = 0)
dftrn.head()
# Out:
#    age  prescript  astigmatic  tear  contact
# 1    1          1           1     1        3
# 2    1          1           1     2        2
# 3    1          1           2     1        3
# 4    1          1           2     2        1
# 6    1          2           1     2        2

# %%
Xtrain = dftrn[['age','prescript','astigmatic','tear']]
Ytrain = dftrn['contact']
Xtest = dftest[['age','prescript','astigmatic','tear']]
Ytest = dftest['contact']

gnb2 = GaussianNB()
gnb2.fit(Xtrain, Ytrain)
Ypred2 = gnb2.predict(Xtest)

acc_score2 = accuracy_score(Ytest, Ypred2)
conf_mat2 = confusion_matrix(Ytest, Ypred2, labels = [0, 1])

print(acc_score2)
print("actual : 0",conf_mat2[0,:2],"\nactual : 1",conf_mat2[1,:2],"\npredicted:  0 1")
# Out:
# 1.0
# actual : 0 [0 0]
# actual : 1 [0 1]
# predicted:  0 1

# %% [markdown]
# ### Task 3
#
# The dataset ```diabetes```is originally from the National Institute of Diabetes and Digestive and Kidney
# Diseases. The objective of the dataset is to diagnostically predict whether a patient has diabetes,
# based on certain diagnostic measurements included in the dataset.
#
# The task is to classify the patients either Diabetes (1) or no diabetes (0).
#
# Split the data 80% for training and 20% for test.
#
# Use GaussianNB, because the variables are now numeric.
#
# You can start with all variables in the model. Then start dropping the variables and look whether the model will improve ofr get worse.
#
#
# ![img](https://i.imgur.com/isADRJf.png)

# %%
df = pd.read_csv('diabetes.csv',index_col = 0)
df.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1

# %%
x=np.array(df["Outcome"]).reshape(-1, 1)
y=np.array(df["DiabetesPedigreeFunction"],df["Glucose"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
gnb2 = GaussianNB()
gnb2.fit(x_train, y_train)
Ypred2 = gnb2.predict(x_test)

acc_score2 = accuracy_score(y_test, Ypred2)
conf_mat2 = confusion_matrix(y_test, Ypred2, labels = [0, 1])

print(acc_score2)
print("actual : 0",conf_mat2[0,:2],"\nactual : 1",conf_mat2[1,:2],"\npredicted:  0 1")
# Out:
# 0.935064935064935
# actual : 0 [144   0]
# actual : 1 [8 0]
# predicted:  0 1
